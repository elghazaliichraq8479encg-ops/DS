# %% [markdown]
# <a href="https://colab.research.google.com/github/elghazaliichraq8479encg-ops/DS/blob/main/ANALYSE/Bienvenue_dans_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
