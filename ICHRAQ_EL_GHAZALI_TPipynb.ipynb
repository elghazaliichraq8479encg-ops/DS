# %% [markdown]
# <a href="https://colab.research.google.com/github/elghazaliichraq8479encg-ops/DS/blob/main/ICHRAQ_EL_GHAZALI_TPipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
